# %%
import cv2 as cv
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pic = cv.imread("puppy.jpg")
plt.imshow(pic)

# %%
pic = cv.cvtColor(pic,cv.COLOR_BGR2RGB)

# %%
type(pic)
# Out:
# numpy.ndarray

# %%
plt.imshow(pic)

# %%
img = cv.cvtColor(pic,cv.COLOR_RGB2HSV)
plt.imshow(img)
